# %%
#Calculation my residuals and plotting them against predictions
residuals = y_test - predictions
#Viewing the redi
plt.scatter(predictions, residuals);

# %%
# #figuring out how columns with dummie are effecting the sale_price
# X = df[list_dummies]
# y = df['sale_price']

# import statsmodels.api as sm

# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123)

# #initiating a model
# model = LinearRegression()
# #fit
# model.fit(X_train, y_train);

# # Create dataframe for all coeficients.
# dummie_coef_df = pd.DataFrame(columns=['X_columns', 'coef_'])

# #and put values in that dataframe: 
# dummie_coef_df['X_columns'] = list_dummies
# dummie_coef_df['coef_'] = model.coef_
# dummie_coef_df['coef_'] = dummie_coef_df['coef_']

# #df['DataFrame column'].round(decimals=number of decimal places needed)

# dummie_coef_df.round(3).sort_values(by='coef_', ascending = False).head(20)

# %%
#Coefficient by neighborhoods
#(how to find a substring in a string found here:
#https://www.geeksforgeeks.org/get-all-rows-in-a-pandas-dataframe-containing-given-substring/)

data = coef_df[coef_df['X_columns'].str.contains("neighborhood")].sort_values(by='coef_', ascending = False)

plt.figure(figsize=(10,11))
sns.set_style("whitegrid")

sns.barplot(data=data, 
            x='coef_', 
            y='X_columns', 
            palette="GnBu_d") ;
plt.title ('The Coef by Neighborhood', 
           size=20);
sns.despine(left=True);
plt.ylabel('');
plt.xlabel('');

# %%
# #Coefficient by ms_zoning

# data = dummie_coef_df[dummie_coef_df['X_columns'].str.contains("ms_zoning")].sort_values(by='coef_', ascending = False)
# #data = data[data['X_columns'] != 'ms_zoning_I (all)']

# plt.figure(figsize=(10,11))
# sns.set_style("whitegrid")

# sns.barplot(data=data, 
#             x= 'coef_', 
#             y='X_columns', 
#             palette="GnBu_d") ;
# plt.title ('The Coef by General Zoning Classification', 
#            size=20);
# sns.despine(left=True);
# plt.ylabel('');
# plt.xlabel('');

# %%
# # Create dataframe for all coeficients.
# coef_df = pd.DataFrame(columns=['X_columns', 'coef_'])

# #and put values in that dataframe: 
# coef_df['X_columns'] = features
# coef_df['coef_'] = lr.coef_


# #Finding Interactions coeficients
# data = coef_df[coef_df['X_columns'].str.contains("synergy")].sort_values(by='coef_', ascending = False)

# plt.figure(figsize=(10,11))
# sns.set_style("whitegrid")

# sns.barplot(data=data, 
#             x= 'coef_', 
#             y='X_columns', 
#             palette="GnBu_d") ;
# plt.title ('The Coefficient by Synergy', 
#            size=20);
# sns.despine(left=True);
# plt.ylabel('');
# plt.xlabel('');

# %%
#Coefficient by ms_subclass


# data = dummie_coef_df[dummie_coef_df['X_columns'].str.contains("ms_subclass")].sort_values(by='coef_', ascending = False)
# data = data[data['X_columns'] != 'ms_subclass_90']

# plt.figure(figsize=(10,11))
# sns.set_style("whitegrid")

# sns.barplot(data=data, 
#             x= 'coef_', 
#             y='X_columns', 
#             palette="GnBu_d") ;
# plt.title ('The Coef by Type of Home', 
#            size=20);
# sns.despine(left=True);
# plt.ylabel('');
# plt.xlabel('');

# %%
#Coefficient by utilities

data = coef_df[coef_df['X_columns'].str.contains("utilities")].sort_values(by='coef_', ascending = False)

plt.figure(figsize=(10,11))
sns.set_style("whitegrid")

sns.barplot(data=data, 
            x= 'coef_', 
            y='X_columns', 
            palette="GnBu_d") ;
plt.title ('The Coef by Utilities', 
           size=20);
sns.despine(left=True);
plt.ylabel('');
plt.xlabel('');

# %%
# #Coefficient by condition1

# data = dummie_coef_df[dummie_coef_df['X_columns'].str.contains("condition1")].sort_values(by='coef_', ascending = False)

# #Renaming columns for the plot
# data['X_columns'] = data['X_columns'].replace({'condition1_Feedr': 
#                                                'Adjacent to feeder street'})
# data['X_columns'] = data['X_columns'].replace({'condition1_Norm': 
#                                                'Normal'})
# data['X_columns'] = data['X_columns'].replace({'condition1_RRNn': 
#                                                'Within 200 of Nort-South Railroad'})
# data['X_columns'] = data['X_columns'].replace({'condition1_RRAn': 
#                                                'Adjacent to North-South Railroad'})
# data['X_columns'] = data['X_columns'].replace({'condition1_PosN': 
#                                                'Near Positive off-site feature(park, greenbelt)'})
# data['X_columns'] = data['X_columns'].replace({'condition1_PosA': 
#                                                'Adjacent to positive features'})
# data['X_columns'] = data['X_columns'].replace({'condition1_RRNe': 
#                                                'Within 200 East-West Railroad'})
# data['X_columns'] = data['X_columns'].replace({'condition1_RRAe': 
#                                                'Adjacent to East-West Railroad'})


# plt.figure(figsize=(10,11))
# sns.set_style("whitegrid")

# sns.barplot(data=data, 
#             x= 'coef_', 
#             y='X_columns', 
#             palette="GnBu_d") ;
# plt.title ('The Coef by Proximity to Various Conditions', 
#            size=25);
# sns.despine(left=True);
# plt.ylabel('');
# plt.xlabel('');
# plt.yticks(size = 20);
# plt.xticks(size = 18);

# %%
# #Coefficient by house_style

# data = dummie_coef_df[dummie_coef_df['X_columns'].str.contains("house_style")].sort_values(by='coef_', ascending = False)
# #Renaming columns for the plot
# data['X_columns'] = data['X_columns'].replace({'house_style_1Story': 
#                                                'One story'})
# data['X_columns'] = data['X_columns'].replace({'house_style_1.5Fin': 
#                                                '1.5 story: 2nd level finished'})
# data['X_columns'] = data['X_columns'].replace({'house_style_1.5Unf': 
#                                                '1.5 story: 2nd level unfinished'})
# data['X_columns'] = data['X_columns'].replace({'house_style_2Story': 
#                                                'Two Story'})
# data['X_columns'] = data['X_columns'].replace({'house_style_2.5Fin': 
#                                                '2.5 story: 2nd level finished'})
# data['X_columns'] = data['X_columns'].replace({'house_style_2.5Unf': 
#                                                '2.5 story: 2nd level unfinished'})
# data['X_columns'] = data['X_columns'].replace({'house_style_SFoyer': 
#                                                'Split Foyer'})
# data['X_columns'] = data['X_columns'].replace({'house_style_SLvl': 
#                                                'Split Level'})

# plt.figure(figsize=(10,11))
# sns.set_style("whitegrid")

# sns.barplot(data=data, 
#             x= 'coef_', 
#             y='X_columns', 
#             palette="GnBu_d") ;
# plt.title ('The Coef by House Style', 
#            size=20);
# sns.despine(left=True);
# plt.ylabel('');
# plt.xlabel('');
# plt.yticks(size = 20);
# plt.xticks(size = 18);

# %%
#Coefficient by exterior1

data = coef_df[coef_df['X_columns'].str.contains("exterior1")].sort_values(by='coef_', ascending = False)
data = data[data['X_columns'] != 'exterior1_CBlock']

plt.figure(figsize=(10,11))
sns.set_style("whitegrid")

sns.barplot(data=data, 
            x= 'coef_', 
            y='X_columns', 
            palette="GnBu_d") ;
plt.title ('The Coef by Exterior Type', 
           size=20);
sns.despine(left=True);
plt.ylabel('');
plt.xlabel('');

# %%
#Coefficient by heating


data = dummie_coef_df[(dummie_coef_df['X_columns'].str.contains("heating")) & 
                              (dummie_coef_df['X_columns'].str.contains("heating_qc")==False)]


data = data.sort_values(by='coef_', ascending = False)

plt.figure(figsize=(10,11))
sns.set_style("whitegrid")

sns.barplot(data=data, 
            x= 'coef_', 
            y='X_columns', 
            palette="GnBu_d") ;
plt.title ('The Coef by Heating Type', 
           size=20);
sns.despine(left=True);
plt.ylabel('');
plt.xlabel('');

# %%
#  TO CREATE LOGARITHM FOR Y !!!!

# y_train_log = np.log(y_train)
# y_test_log = np.log(y_test)

# #and then redo the model again
# lr = LinearRegression()
# lr.fit(X_train, y_train_log);
# cross_val_score(lr, X_train, y_train_log, cv=5).mean()

# ??? predictions = lr.predict(X_test)
# print_metrics(y_test_log, predictions, len(features));

# #Epsilons, your errrors
# residuals = y_test - predictions
# #residual plot
# plt.scatter(predictions, residuals);

# %%
# df['log_abv_grd_area'] = np.log(df['abv_grd_area'])

# # Vewing AGAIN relationship between house sales price
# # and total area above groud
# sns.scatterplot(data = df, x = 'log_abv_grd_area', y = 'sale_price');
# sns.set_style("whitegrid")

# plt.title ('Relationship between Sales Price and Square Footage', 
#            size=15);
# plt.ylabel('');
# plt.xlabel('Total House Square Footage');

# %%
#aesthetics of seaborn plots
https://seaborn.pydata.org/tutorial/aesthetics.html

# %%
#####Model2

# #Preprocessig and Modeling
# X = df[synergy_features]
# y = df['sale_price']

# #initiating a multiple regression model
# lr = LinearRegression()

# #randomly subset of rows into to dataframes: train and test
# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# #checking how the split worked
# print(f'X_train.shape = {X_train.shape}')
# print(f'X_train.shape = {X_test.shape}')

# cv_score = cross_val_score(lr, X_train, y_train, cv=5).mean()
# print(f'cross validation score = {cv_score}')

# #Fit the model to the training data, 
# lr.fit(X_train, y_train);

# #Evaluate the training and test scores:
# #Train score
# print(f'lr.score train = {lr.score(X_train, y_train)}')

# #Test score
# print(f'lr.score test = {lr.score(X_test, y_test)}')

# predictions = lr.predict(X_test)
# print_metrics(y_test, predictions, len(features));
